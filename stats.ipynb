# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
stats = pd.read_csv("/Users/xiaochiu/ttt/game_stats.csv")
stats
# Out:
#     Unnamed: 0  Game ID Player 1 Player 1 Type Player 2 Player 2 Type Winner  \
# 0            0        1      Bot           Bot     Bot2           Bot   Draw
# 1            0        2      Bot           Bot     Bot2           Bot      O
# 2            0        3      Bot           Bot     Bot2           Bot      X
# 3            0        4      Bot           Bot     Bot2           Bot      X
# 4            0        5      Bot           Bot     Bot2           Bot   Draw
# 5            0        6      Bot           Bot     Bot2           Bot      X
# 6            0        7      Bot           Bot     Bot2           Bot   Draw
# 7            0        8      Bot           Bot     Bot2           Bot   Draw
# 8            0        9      Bot           Bot     Bot2           Bot      O
# 9            0       10      Bot           Bot     Bot2           Bot      X
# 10           0       11      Bot           Bot     Bot2           Bot   Draw
# 11           0       12      Bot           Bot     Bot2           Bot      X
# 12           0       13      Bot           Bot     Bot2           Bot      O
# 13           0       14      Bot           Bot     Bot2           Bot   Draw
# 14           0       15      Bot           Bot     Bot2           Bot      X
# 15           0       16      Bot           Bot     Bot2           Bot      X
# 16           0       17      Bot           Bot     Bot2           Bot      X
# 17           0       18      Bot           Bot     Bot2           Bot   Draw
# 18           0       19      Bot           Bot     Bot2           Bot      O
# 19           0       20     Mary         Human     Bot2           Bot   Draw
# 20           0       21     Mary         Human     Bot2           Bot      X
# 21           0       22     Mary         Human     Bot2           Bot      X
# 22           0       23      Bot           Bot    David         Human      O
# 23           0       24      Bot           Bot    David         Human      O
# 24           0       25     Mary         Human    David         Human   Draw
# 25           0       26     Mary         Human    David         Human      X
# 26           0       27     Mary         Human    David         Human   Draw
# 27           0       28     Mary         Human    David         Human   Draw
# 28           0       29      Bot           Bot    David         Human   Draw
#
#    Winner Name Winner Type  Moves
# 0          NaN         NaN      7
# 1         Bot2         Bot      8
# 2          Bot         Bot      7
# 3          Bot         Bot      7
# 4          NaN         NaN      6
# 5          Bot         Bot      7
# 6          NaN         NaN      6
# 7          NaN         NaN      7
# 8         Bot2         Bot      8
# 9          Bot         Bot      7
# 10         NaN         NaN      7
# 11         Bot         Bot      7
# 12        Bot2         Bot      6
# 13         NaN         NaN      7
# 14         Bot         Bot      7
# 15         Bot         Bot      7
# 16         Bot         Bot      7
# 17         NaN         NaN      5
# 18        Bot2         Bot      8
# 19         NaN         NaN      5
# 20        Mary       Human      7
# 21        Mary       Human      5
# 22       David       Human      8
# 23       David       Human      6
# 24         NaN         NaN      7
# 25        Mary       Human      9
# 26         NaN         NaN      9
# 27         NaN         NaN      8
# 28         NaN         NaN      7

# %%
winner = stats["Winner"]
winner
# Out:
# 0     Draw
# 1        O
# 2        X
# 3        X
# 4     Draw
# 5        X
# 6     Draw
# 7     Draw
# 8        O
# 9        X
# 10    Draw
# 11       X
# 12       O
# 13    Draw
# 14       X
# 15       X
# 16       X
# 17    Draw
# 18       O
# 19    Draw
# 20       X
# 21       X
# 22       O
# 23       O
# 24    Draw
# 25       X
# 26    Draw
# 27    Draw
# 28    Draw
# Name: Winner, dtype: object

# %%
stats[["Winner","Winner Type"]]
# Out:
#    Winner Winner Type
# 0    Draw         NaN
# 1       O         Bot
# 2       X         Bot
# 3       X         Bot
# 4    Draw         NaN
# 5       X         Bot
# 6    Draw         NaN
# 7    Draw         NaN
# 8       O         Bot
# 9       X         Bot
# 10   Draw         NaN
# 11      X         Bot
# 12      O         Bot
# 13   Draw         NaN
# 14      X         Bot
# 15      X         Bot
# 16      X         Bot
# 17   Draw         NaN
# 18      O         Bot
# 19   Draw         NaN
# 20      X       Human
# 21      X       Human
# 22      O       Human
# 23      O       Human
# 24   Draw         NaN
# 25      X       Human
# 26   Draw         NaN
# 27   Draw         NaN
# 28   Draw         NaN

# %%
stats["Winner"] != "Draw"
# Out:
# 0     False
# 1      True
# 2      True
# 3      True
# 4     False
# 5      True
# 6     False
# 7     False
# 8      True
# 9      True
# 10    False
# 11     True
# 12     True
# 13    False
# 14     True
# 15     True
# 16     True
# 17    False
# 18     True
# 19    False
# 20     True
# 21     True
# 22     True
# 23     True
# 24    False
# 25     True
# 26    False
# 27    False
# 28    False
# Name: Winner, dtype: bool

# %%
stats[stats["Winner"]!= "Draw"]
# Out:
#     Unnamed: 0  Game ID Player 1 Player 1 Type Player 2 Player 2 Type Winner  \
# 1            0        2      Bot           Bot     Bot2           Bot      O
# 2            0        3      Bot           Bot     Bot2           Bot      X
# 3            0        4      Bot           Bot     Bot2           Bot      X
# 5            0        6      Bot           Bot     Bot2           Bot      X
# 8            0        9      Bot           Bot     Bot2           Bot      O
# 9            0       10      Bot           Bot     Bot2           Bot      X
# 11           0       12      Bot           Bot     Bot2           Bot      X
# 12           0       13      Bot           Bot     Bot2           Bot      O
# 14           0       15      Bot           Bot     Bot2           Bot      X
# 15           0       16      Bot           Bot     Bot2           Bot      X
# 16           0       17      Bot           Bot     Bot2           Bot      X
# 18           0       19      Bot           Bot     Bot2           Bot      O
# 20           0       21     Mary         Human     Bot2           Bot      X
# 21           0       22     Mary         Human     Bot2           Bot      X
# 22           0       23      Bot           Bot    David         Human      O
# 23           0       24      Bot           Bot    David         Human      O
# 25           0       26     Mary         Human    David         Human      X
#
#    Winner Name Winner Type  Moves
# 1         Bot2         Bot      8
# 2          Bot         Bot      7
# 3          Bot         Bot      7
# 5          Bot         Bot      7
# 8         Bot2         Bot      8
# 9          Bot         Bot      7
# 11         Bot         Bot      7
# 12        Bot2         Bot      6
# 14         Bot         Bot      7
# 15         Bot         Bot      7
# 16         Bot         Bot      7
# 18        Bot2         Bot      8
# 20        Mary       Human      7
# 21        Mary       Human      5
# 22       David       Human      8
# 23       David       Human      6
# 25        Mary       Human      9

# %%
stats[stats["Winner Name"] == "Mary"]
# Out:
#     Unnamed: 0  Game ID Player 1 Player 1 Type Player 2 Player 2 Type Winner  \
# 20           0       21     Mary         Human     Bot2           Bot      X
# 21           0       22     Mary         Human     Bot2           Bot      X
# 25           0       26     Mary         Human    David         Human      X
#
#    Winner Name Winner Type  Moves
# 20        Mary       Human      7
# 21        Mary       Human      5
# 25        Mary       Human      9

# %%
# totoal num of games
stats["Game ID"].count()
# Out:
# 29

# %%
# winning count
stats["Winner Name"].value_counts()
# Out:
# Bot      8
# Bot2     4
# Mary     3
# David    2
# Name: Winner Name, dtype: int64

# %%
rankings = pd. DataFrame(columns=[
    "Player Name",
    "Games",
    "Wins",
    "Draws",
    "Winning Rate"
])
rankings
# Out:
# Empty DataFrame
# Columns: [Player Name, Games, Wins, Draws, Winning Rate]
# Index: []

# %%
stats
# Out:
#     Unnamed: 0  Game ID Player 1 Player 1 Type Player 2 Player 2 Type Winner  \
# 0            0        1      Bot           Bot     Bot2           Bot   Draw
# 1            0        2      Bot           Bot     Bot2           Bot      O
# 2            0        3      Bot           Bot     Bot2           Bot      X
# 3            0        4      Bot           Bot     Bot2           Bot      X
# 4            0        5      Bot           Bot     Bot2           Bot   Draw
# 5            0        6      Bot           Bot     Bot2           Bot      X
# 6            0        7      Bot           Bot     Bot2           Bot   Draw
# 7            0        8      Bot           Bot     Bot2           Bot   Draw
# 8            0        9      Bot           Bot     Bot2           Bot      O
# 9            0       10      Bot           Bot     Bot2           Bot      X
# 10           0       11      Bot           Bot     Bot2           Bot   Draw
# 11           0       12      Bot           Bot     Bot2           Bot      X
# 12           0       13      Bot           Bot     Bot2           Bot      O
# 13           0       14      Bot           Bot     Bot2           Bot   Draw
# 14           0       15      Bot           Bot     Bot2           Bot      X
# 15           0       16      Bot           Bot     Bot2           Bot      X
# 16           0       17      Bot           Bot     Bot2           Bot      X
# 17           0       18      Bot           Bot     Bot2           Bot   Draw
# 18           0       19      Bot           Bot     Bot2           Bot      O
# 19           0       20     Mary         Human     Bot2           Bot   Draw
# 20           0       21     Mary         Human     Bot2           Bot      X
# 21           0       22     Mary         Human     Bot2           Bot      X
# 22           0       23      Bot           Bot    David         Human      O
# 23           0       24      Bot           Bot    David         Human      O
# 24           0       25     Mary         Human    David         Human   Draw
# 25           0       26     Mary         Human    David         Human      X
# 26           0       27     Mary         Human    David         Human   Draw
# 27           0       28     Mary         Human    David         Human   Draw
# 28           0       29      Bot           Bot    David         Human   Draw
#
#    Winner Name Winner Type  Moves
# 0          NaN         NaN      7
# 1         Bot2         Bot      8
# 2          Bot         Bot      7
# 3          Bot         Bot      7
# 4          NaN         NaN      6
# 5          Bot         Bot      7
# 6          NaN         NaN      6
# 7          NaN         NaN      7
# 8         Bot2         Bot      8
# 9          Bot         Bot      7
# 10         NaN         NaN      7
# 11         Bot         Bot      7
# 12        Bot2         Bot      6
# 13         NaN         NaN      7
# 14         Bot         Bot      7
# 15         Bot         Bot      7
# 16         Bot         Bot      7
# 17         NaN         NaN      5
# 18        Bot2         Bot      8
# 19         NaN         NaN      5
# 20        Mary       Human      7
# 21        Mary       Human      5
# 22       David       Human      8
# 23       David       Human      6
# 24         NaN         NaN      7
# 25        Mary       Human      9
# 26         NaN         NaN      9
# 27         NaN         NaN      8
# 28         NaN         NaN      7

# %%
stats[["Winner Name","Winner Type"]].groupby("Winner Type").count()
# Out:
#              Winner Name
# Winner Type
# Bot                   12
# Human                  5

# %%
# games count by player， winning rate
all_names = pd.concat([stats["Player 1"], stats["Player 2"]], ignore_index=True).unique().tolist()
rankings["Player Name"] = all_names
rankings["Games"] = [((stats["Player 1"] == name) | (stats["Player 2"] == name)).sum() for name in all_names]
rankings["Wins"] = [(stats["Winner Name"] == name).sum() for name in all_names]
draw_games = stats[stats["Winner"] == "Draw"]
rankings["Draws"] = [((draw_games["Player 1"] == name) | (draw_games["Player 2"] == name)).sum() for name in all_names]
rankings["Winning Rate"] = rankings["Wins"] / rankings["Games"]
rankings
# Out:
#   Player Name  Games  Wins  Draws  Winning Rate  Player Type
# 0         Bot     22     8      8      0.363636           22
# 1        Mary      7     3      4      0.428571            7
# 2        Bot2     22     4      8      0.181818           22
# 3       David      7     2      4      0.285714            7

# %%
# Pie chart:
labels = 'Bot', 'Human'
sizes = [12, 5]
explode = (0, 0)  # no"explode"

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=False, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
ax1.set_title('Human vs. Bot Wins')

plt.show()

# %%
plt.rcdefaults()
fig, ax = plt.subplots()

player = ('Bot', 'Bot 2', 'Mary', 'David')
wins = (8,4,3,2)

ax.barh(y_pos, wins, align='center')
ax.set_yticks(y_pos, labels=player)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Wins')
ax.set_title('Winner Ranking')

plt.show()

# %%
stats.plot.scatter(x = "Game ID", y = "Moves")
# Out:
# <AxesSubplot:xlabel='Game ID', ylabel='Moves'>
